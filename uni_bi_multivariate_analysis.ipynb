# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudraps07/minor-project/blob/main/uni_bi_multivariate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# #univariate analysis

# %%
df_setosa=df.loc[df["species"]=="setosa"]

# %%
df_virginica=df.loc[df["species"]=="virginica"]

# %%
df_versicolor=df.loc[df["species"]=="versicolor"]

# %%
plt.plot(df_virginica["petal_length"])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df_setosa["petal_length"],np.zeros_like(df_setosa["petal_length"]),'o')
plt.plot(df_virginica["petal_length"],np.zeros_like(df_virginica["petal_length"]),'o')
plt.plot(df_versicolor["petal_length"],np.zeros_like(df_versicolor["petal_length"]),'o')

plt.xlabel("petal length")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df_setosa["petal_length"],np.zeros_like(df_setosa["petal_length"]),'o')


plt.xlabel("petal length")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df_virginica["petal_length"],np.zeros_like(df_virginica["petal_length"]),'o')


plt.xlabel("petal length")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df_versicolor["petal_length"],np.zeros_like(df_versicolor["petal_length"]),'o')

plt.xlabel("petal length")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df_setosa["petal_length"],np.zeros_like(df_setosa["petal_length"]),'o')
plt.plot(df_virginica["petal_length"],np.zeros_like(df_virginica["petal_length"]),'o')


plt.xlabel("petal length")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(df_virginica["petal_length"],np.zeros_like(df_virginica["petal_length"]),'o')
plt.plot(df_versicolor["petal_length"],np.zeros_like(df_versicolor["petal_length"]),'o')

plt.xlabel("petal length")
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-e9db37766fb2> in <module>
#       1 plt.plot(df_virginica["petal_length"],np.zeros_like(df_virginica["petal_length"]),'o')
# ----> 2 plt.plot(df_versicolor["petal_length"],np.zeros_like(df_versicolor["petal_length"]),'o').add_legend()
#       3
#       4 plt.xlabel("petal length")
#       5 plt.show
#
# AttributeError: 'list' object has no attribute 'add_legend'

# %% [markdown]
# #Bivariate Analysis

# %%
sns.FacetGrid(df,hue="species",size=5).map(plt.scatter,"sepal_length","sepal_width").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="species",size=5).map(plt.scatter,"petal_length","petal_width").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #Multivariate Analysis

# %%
sns.pairplot(df,hue="species",size=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
